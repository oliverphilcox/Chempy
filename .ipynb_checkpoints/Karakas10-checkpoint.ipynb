# %% [markdown]
# ## Karakas 2010 net yields from MCMC
#
# Run the multi_star_optimization script to calculate the posterior parameter set with Karakas 10 yield (via MCMC), using the new model error beta function marginalization.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from Chempy.wrapper import multi_star_optimization # (there will be many gas reservoir/upper border errors but these can be ignored)
# %timeit -n 1 -r 1 multi_star_optimization()

# This was done on a different PC but results are shown below
# Out:
# ['Proto-sun']
# first minimization for each star separately took:  0 seconds
# [-9.1534087658941345]
# step 1 global minimization took: 22 seconds
# step 1 local minimization took:  1 seconds
# [-9.1534087658941345, -9.1534087658941345]
# step 2 global minimization took: 23 seconds
# step 2 local minimization took:  1 seconds
# [array([[-2.29, -2.75, -0.8 , -0.3 ,  0.55,  0.5 ]]), 'initial minimization', (array([-2.29, -2.75, -0.8 ]), -9.1534087658941345), 'step 1 global minimization', array([[-2.29, -2.75, -0.8 , -0.3 ,  0.55,  0.5 ]]), 'step 1 local minimization', (array([-2.29, -2.75, -0.8 ]), -9.1534087658941345), 'step 2 global minimization', array([[-2.29, -2.75, -0.8 , -0.3 ,  0.55,  0.5 ]]), 'step 2 local minimization', [-9.1534087658941345, -9.1534087658941345]]
# step  1 of  1000
# -2.86218028883 -2.86243071933
# calculation so far took 20.709133863449097  seconds
# step  2 of  1000
# -2.86218028883 -2.86263443073
# calculation so far took 24.545960426330566  seconds
# step  3 of  1000
# -2.86218028883 -2.86329096509
# calculation so far took 28.517720222473145  seconds
# step  4 of  1000
# -2.86218028883 -2.86461832541
# calculation so far took 32.640655279159546  seconds
# step  5 of  1000
# -2.86218028883 -2.86821184178
# calculation so far took 36.55469822883606  seconds
# step  6 of  1000
# -2.86218028883 -2.87243330649
# calculation so far took 40.47645688056946  seconds
# step  7 of  1000
# -2.86218028883 -2.87827353004
# calculation so far took 44.334632873535156  seconds
# step  8 of  1000
# -2.86218028883 -2.90478677582
# calculation so far took 48.429505586624146  seconds
# step  9 of  1000
# -2.86218028883 -2.93018765223
# calculation so far took 52.46299862861633  seconds
# step  10 of  1000
# -2.86218028883 -3.04405594142
# calculation so far took 56.26463031768799  seconds
# step  11 of  1000
# -2.86218028883 -3.15147602801
# calculation so far took 60.033018827438354  seconds
# step  12 of  1000
# -2.86218028883 -3.3363418268
# calculation so far took 64.52094435691833  seconds
# step  13 of  1000
# -2.86218028883 -3.62226145486
# calculation so far took 68.92129826545715  seconds
# step  14 of  1000
# -2.86218028883 -3.82363012968
# calculation so far took 73.18154859542847  seconds
# step  15 of  1000
# -2.86218028883 -4.17264217827
# calculation so far took 77.24172306060791  seconds
# step  16 of  1000
# -2.86218028883 -4.7059111476
# calculation so far took 80.99595236778259  seconds
# step  17 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_N_0 upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: outflow_feedback_fraction upper border is violated
# -2.86218028883 -4.98840782945
# calculation so far took 84.9912645816803  seconds
# step  18 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_N_0 upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: outflow_feedback_fraction lower border is violated
# -2.86218028883 -4.88568768215
# calculation so far took 89.01598453521729  seconds
# step  19 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86218028883 -5.05445195806
# calculation so far took 93.4630880355835  seconds
# step  20 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86218028883 -4.91104302103
# calculation so far took 97.3244481086731  seconds
# step  21 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_N_0 upper border is violated
# -2.86218028883 -4.98740356911
# calculation so far took 101.14916038513184  seconds
# step  22 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: outflow_feedback_fraction upper border is violated
# -2.86218028883 -5.09630683039
# calculation so far took 104.9952781200409  seconds
# step  23 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86218028883 -5.19036188699
# calculation so far took 108.8303370475769  seconds
# step  24 of  1000
# -2.86218028883 -5.06950440623
# calculation so far took 112.7548816204071  seconds
# step  25 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86218028883 -5.23766338737
# calculation so far took 116.88592839241028  seconds
# step  26 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86218028883 -5.10971719327
# calculation so far took 120.68165326118469  seconds
# step  27 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: log10_N_0 lower border is violated
# -2.86218028883 -5.11869292556
# calculation so far took 124.57397890090942  seconds
# step  28 of  1000
# -2.86218028883 -5.15910819057
# calculation so far took 128.51113939285278  seconds
# step  29 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86218028883 -5.25095037738
# calculation so far took 132.2744812965393  seconds
# step  30 of  1000
# -2.86218028883 -5.26466872105
# calculation so far took 136.08696484565735  seconds
# step  31 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86218028883 -5.09378510697
# calculation so far took 140.17534732818604  seconds
# step  32 of  1000
# -2.86218028883 -4.80569260155
# calculation so far took 144.27393674850464  seconds
# step  33 of  1000
# -2.86218028883 -5.04549867768
# calculation so far took 148.1905391216278  seconds
# step  34 of  1000
# -2.86218028883 -5.07948648331
# calculation so far took 152.40537071228027  seconds
# step  35 of  1000
# -2.86218028883 -5.23649359161
# calculation so far took 156.1213071346283  seconds
# step  36 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: log10_N_0 lower border is violated
# -2.86218028883 -5.45179678841
# calculation so far took 159.83865332603455  seconds
# step  37 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86218028883 -5.45181604921
# calculation so far took 163.54474401474  seconds
# step  38 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: outflow_feedback_fraction lower border is violated
# -2.86218028883 -5.32824471166
# calculation so far took 167.34110856056213  seconds
# step  39 of  1000
# -2.86218028883 -5.22429101163
# calculation so far took 171.25298285484314  seconds
# step  40 of  1000
# -2.86218028883 -5.17308158439
# calculation so far took 175.11674666404724  seconds
# step  41 of  1000
# -2.86218028883 -5.28928749112
# calculation so far took 178.98365116119385  seconds
# step  42 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_N_0 upper border is violated
# -2.86218028883 -5.48371493763
# calculation so far took 182.93472170829773  seconds
# step  43 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: outflow_feedback_fraction lower border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_N_0 upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_N_0 upper border is violated
# -2.86218028883 -5.46366002787
# calculation so far took 186.66241931915283  seconds
# step  44 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86218028883 -5.70108970256
# calculation so far took 191.1547453403473  seconds
# step  45 of  1000
# -2.86218028883 -5.79816334577
# calculation so far took 195.2326045036316  seconds
# step  46 of  1000
# -2.86218028883 -5.81568115878
# calculation so far took 199.7071828842163  seconds
# step  47 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86218028883 -5.65367273645
# calculation so far took 203.64190578460693  seconds
# step  48 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86218028883 -5.57379862231
# calculation so far took 208.63001608848572  seconds
# step  49 of  1000
# -2.86218028883 -5.66822901924
# calculation so far took 212.6932830810547  seconds
# step  50 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86218028883 -5.69293612449
# calculation so far took 216.45142936706543  seconds
# step  51 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_N_0 upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: outflow_feedback_fraction upper border is violated
# -2.86218028883 -5.37592104371
# calculation so far took 220.813485622406  seconds
# step  52 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86218028883 -5.68711429194
# calculation so far took 224.73853874206543  seconds
# step  53 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
# ...
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86218028883 -6.16337051312
# posterior -1, -100, -200 -6.16337051312 -5.98818159701 -5.54548775093
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1268.2461109161377  seconds
# step  292 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86218028883 -6.04291478704
# posterior -1, -100, -200 -6.04291478704 -5.83110602578 -5.77060546526
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1272.36843085289  seconds
# step  293 of  1000
# -2.86218028883 -5.82555806917
# posterior -1, -100, -200 -5.82555806917 -5.58619663851 -5.62795719374
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1276.1442189216614  seconds
# step  294 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: log10_sn1a_time_delay lower border is violated
# -2.86218028883 -5.83002005764
# posterior -1, -100, -200 -5.83002005764 -5.57427669847 -5.85720580014
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1279.8683841228485  seconds
# step  295 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: log10_sn1a_time_delay lower border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: outflow_feedback_fraction lower border is violated
# -2.86218028883 -5.63130938433
# posterior -1, -100, -200 -5.63130938433 -5.85738710936 -5.78268029042
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1284.8091354370117  seconds
# step  296 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86218028883 -5.68757124431
# posterior -1, -100, -200 -5.68757124431 -5.74085147852 -5.98017530763
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1288.6117541790009  seconds
# step  297 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: outflow_feedback_fraction lower border is violated
# -2.86218028883 -5.73002414208
# posterior -1, -100, -200 -5.73002414208 -5.84751132566 -6.08395665596
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1292.326756477356  seconds
# step  298 of  1000
# -2.86218028883 -5.44013939367
# posterior -1, -100, -200 -5.44013939367 -5.75091769887 -5.91120531807
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1296.1696519851685  seconds
# step  299 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86218028883 -5.45102871033
# posterior -1, -100, -200 -5.45102871033 -5.60451311725 -6.10586783513
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1299.9327266216278  seconds
# step  300 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: outflow_feedback_fraction upper border is violated
# -2.86218028883 -5.47175082577
# posterior -1, -100, -200 -5.47175082577 -5.80245201405 -5.9067762823
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1303.748883008957  seconds
# step  301 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: outflow_feedback_fraction lower border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86218028883 -5.48011461414
# posterior -1, -100, -200 -5.48011461414 -5.55997673134 -5.85583026546
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1308.2565612792969  seconds
# step  302 of  1000
# -2.86218028883 -5.44130823805
# posterior -1, -100, -200 -5.44130823805 -5.37763141265 -6.17081976054
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1312.1137301921844  seconds
# step  303 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: outflow_feedback_fraction lower border is violated
# -2.86218028883 -5.48964486117
# posterior -1, -100, -200 -5.48964486117 -5.40900132901 -5.99357350637
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1315.8441152572632  seconds
# step  304 of  1000
# -2.86218028883 -5.4858588484
# posterior -1, -100, -200 -5.4858588484 -5.4633010033 -5.80672580502
# posterior 0, 100, 200 -2.86218028883 -6.10586783513 -5.60451311725
# calculation so far took 1319.5621058940887  seconds
# 1 loop, best of 1: 22min 45s per loop

# %% [markdown]
# 1.44405552172 -1.51489443104
# posterior -1, -100, -200 -1.51489443104 -1.53393613939 -1.26114312589
# posterior 0, 100, 200 1.44405552172 -1.37090752971 -1.43192489745
# calculation so far took 3788.451721906662  seconds
# 1 loop, best of 1: 1h 4min 54s per loop

# %% [markdown]
# This takes a time of 1 hour, 4 min, 54 seconds to run. Data is in the mcmc/ folder - copy this into the karakas10 folder to save. Output is shown above.

# %%
## Now restructure the chain

from Chempy.plot_mcmc import restructure_chain
restructure_chain('karakas10/')
# Out:
# blob shape =  (64, 303, 22, 1) probably some runs did not return results and were stored anyway.
# The chain has a length of 303 iterations, each iteration having 64 evaluations/walkers
# Mean posteriors at the beginning and the end of the chain:
# -1.51489443104 1.44405552172
# Mean posteriors after the burn-in tail is cut out:
# -1.51489443104 -1.59169875752
# We are left with a sample of 4992 posterior evaluations from the converged MCMC chain
# We have 4992 iterations good enough posterior, their posteriors range from
# 1.42550044505 -9.29678471566
# Highest posterior was obtained at parameters:  [[-2.5882797  -2.79484145 -0.78438053 -0.28514599  0.56036285  0.53814161]]
# Number of unique posterior values:  2573
# Inferred marginalized parameter distributions are:
# 0 -2.57935719605 +- 0.118345442445
# 1 -2.82232215508 +- 0.152689627696
# 2 -0.843873449484 +- 0.287431044791
# 3 -0.289613380669 +- 0.265267644326
# 4 0.556672616494 +- 0.098909488157
# 5 0.504011697614 +- 0.103684580087

# %%
## Plot the posterior and prior values and correlation grid
from Chempy.plot_mcmc import plot_mcmc_chain_with_prior
plot_mcmc_chain_with_prior('karakas10/',use_prior = True, only_first_star = False,plot_true_parameters = False,plot_only_SSP_parameter = False)

# %% [markdown]
# ## Using Neural Network - No error marginalization

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
## Now restructure the chain - with output data in karakas10_neural folder
from Chempy.plot_mcmc import restructure_chain
restructure_chain('karakas10_neural/')
# Out:
# blob shape =  (64, 304, 22, 1) probably some runs did not return results and were stored anyway.
# The chain has a length of 304 iterations, each iteration having 64 evaluations/walkers
# Mean posteriors at the beginning and the end of the chain:
# -377.289039669 -374.080293557
# Mean posteriors after the burn-in tail is cut out:
# -377.289039669 -377.36134141
# We are left with a sample of 4992 posterior evaluations from the converged MCMC chain
# We have 4990 iterations good enough posterior, their posteriors range from
# 2 runs of the stabilised MCMC had a posterior that was worse -15 ln
# -374.182466061 -387.494036697
# Highest posterior was obtained at parameters:  [[-2.35691092 -2.81170311 -0.76358795 -0.38266699  0.56708361  0.50881256]]
# Number of unique posterior values:  2557
# Inferred marginalized parameter distributions are:
# 0 -2.3140203991 +- 0.331056620906
# 1 -2.73069947731 +- 0.294423010012
# 2 -0.798724819095 +- 0.282893125355
# 3 -0.331859958929 +- 0.321906174234
# 4 0.551582873725 +- 0.0969386959931
# 5 0.496655674822 +- 0.0941839919927
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x7f7646e8e5e8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-5-a51a85e51386> in <module>()
#       1 ## Now restructure the chain - with output data in karakas10_neural folder
#       2 from Chempy.plot_mcmc import restructure_chain
# ----> 3 restructure_chain('karakas10_neural/')
#
# /home/philcox/Chempy/Chempy/plot_mcmc.py in restructure_chain(directory, parameter_names)
#     184         axes[i+1].set_ylabel('posterior')
#     185
# --> 186         fig.savefig("%schain.png" %(directory))
#     187         plt.clf()
#     188         plt.figure(figsize=(14.69,30.27), dpi=100)
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1571             self.set_frameon(frameon)
#    1572
# -> 1573         self.canvas.print_figure(*args, **kwargs)
#    1574
#    1575         if frameon:
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2250                 orientation=orientation,
#    2251                 bbox_inches_restore=_bbox_inches_restore,
# -> 2252                 **kwargs)
#    2253         finally:
#    2254             if bbox_inches and restore_bbox:
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     554
#     555         try:
# --> 556             _png.write_png(renderer._renderer, filename_or_obj, self.figure.dpi)
#     557         finally:
#     558             if close:
#
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f7673f2de08> returned a result with an error set

# %%
## Plot the posterior and prior values and correlation grid
from Chempy.plot_mcmc import plot_mcmc_chain_with_prior
plot_mcmc_chain_with_prior('karakas10_neural/',use_prior = True, only_first_star = False,plot_true_parameters = False,plot_only_SSP_parameter = False)

# %% [markdown]
# **Ensure parameter.py file is set to use Karakas10 yields before running the below**
# (i.e. yield_table_name_agb_index = 2 in parameter.py)

# %%
# Create output for best-fit parameters
from Chempy.cem_function import cem2, extract_parameters_and_priors
from Chempy.parameter import ModelParameters
a=ModelParameters()
a.p0 = np.array([-2.58,-2.82,-0.86,-0.31,0.55,0.51]) # Parameters found by model
a = extract_parameters_and_priors(a.p0, a) # To update to new model
abundances, names = cem2(a) # predict abundances

# %%
# Load in proto-sun abundances and errors (remove last value (solar age))
proto_sun = np.load('Chempy/input/stars/Proto-sun.npy')
proto_sun_abundance = []
proto_sun_error = []
model_abundance = []
#names = np.asarray(names) # For compatibility

# Calculate model abundance in same order as proto-sun
for i,item in enumerate(proto_sun.dtype.names[:-1]):
    for j,jtem in enumerate(names):
        if jtem == item:
            model_abundance.append(abundances[j])
    #model_abundance.append(abundances[np.where(names==item)])
    proto_sun_abundance.append(proto_sun[0][i])
    proto_sun_error.append(proto_sun[1][i])
    
# Load abundance names ([X/Fe]) in correct order
abundance_names = []
for item in proto_sun.dtype.names[:-1]:
    if item != 'Fe':
        abundance_names.append('[%s/Fe]' %(item))
    else:
        abundance_names.append('[Fe/H]')

# %%
# Plot figure comparing model and observational abundancess
fig = plt.figure(figsize=(30.69,8.27), dpi=100)
plt.clf()
text_size = 20
plt.rc('font', family='serif',size = text_size)
plt.rc('xtick', labelsize=text_size)
plt.rc('ytick', labelsize=text_size)
plt.rc('axes', labelsize=text_size, lw=1.)
plt.rc('lines', linewidth = 1.)
plt.rcParams['ytick.major.pad']='8'
plt.rcParams['text.latex.preamble']=[r"\usepackage{libertine}"]
params = {'text.usetex' : True,'font.size' : 16,'font.family' : 'libertine','text.latex.unicode': True}
ax = fig.add_subplot(111)
plt.plot(np.arange(len(abundance_names)),model_abundance,label='Final model abundances',linestyle='-') # Plot model data
plt.errorbar(np.arange(len(abundance_names)),proto_sun_abundance,xerr=None,yerr=proto_sun_error,linestyle = '',mew=3,marker='x',capthick =3,capsize = 20, ms = 10,elinewidth=3,label='proto-solar')
plt.ylim((-0.5,0.5))
plt.xticks(np.arange(len(a.element_names)),abundance_names)
plt.ylabel("abundance relative to solar in dex")
plt.xlabel("Element")
plt.title("Comparing proto-solar model and predicted abundances")
plt.legend()
savefig('karakas10/AbundancePlot')

# %% [markdown]
# ## Rerun without error optimization
# Set model errors to zero to test with no error marginalization, and stored in karakas10_zero_error

# %% [markdown]
# #### Change these settings in the parameter.py file, since multi_star_optimization resets parameters to defaults.
#
# a.error_marginalization = False
# a.zero_model_error = True

# %%
from Chempy.wrapper import multi_star_optimization # Run code without error optimization
# errors in abundance['Fe'] are fine, since initial Fe mass is zero, so abundance is -inf
# %timeit -n 1 -r 1 multi_star_optimization() # Time running - use -n, -r to set only 1 iteration of code
# (Run on a faster PC)
# Out:
# ['Proto-sun']
# first minimization for each star separately took:  0 seconds
# [-9.1534087658941345]
# step 1 global minimization took: 22 seconds
# step 1 local minimization took:  1 seconds
# [-9.1534087658941345, -9.1534087658941345]
# step 2 global minimization took: 21 seconds
# step 2 local minimization took:  1 seconds
# [array([[-2.29, -2.75, -0.8 , -0.3 ,  0.55,  0.5 ]]), 'initial minimization', (array([-2.29, -2.75, -0.8 ]), -9.1534087658941345), 'step 1 global minimization', array([[-2.29, -2.75, -0.8 , -0.3 ,  0.55,  0.5 ]]), 'step 1 local minimization', (array([-2.29, -2.75, -0.8 ]), -9.1534087658941345), 'step 2 global minimization', array([[-2.29, -2.75, -0.8 , -0.3 ,  0.55,  0.5 ]]), 'step 2 local minimization', [-9.1534087658941345, -9.1534087658941345]]
# step  1 of  1000
# -2.86215594683 -2.86234523353
# calculation so far took 18.75343918800354  seconds
# step  2 of  1000
# -2.86215594683 -2.86289045204
# calculation so far took 22.55124044418335  seconds
# step  3 of  1000
# -2.86215594683 -2.86390182608
# calculation so far took 26.92271065711975  seconds
# step  4 of  1000
# -2.86215594683 -2.86522567951
# calculation so far took 30.829922914505005  seconds
# step  5 of  1000
# -2.86215594683 -2.86693323791
# calculation so far took 35.1606125831604  seconds
# step  6 of  1000
# -2.86215594683 -2.87140543685
# calculation so far took 39.164050817489624  seconds
# step  7 of  1000
# -2.86215594683 -2.87906582277
# calculation so far took 43.04547095298767  seconds
# step  8 of  1000
# -2.86215594683 -2.88595785666
# calculation so far took 46.930662870407104  seconds
# step  9 of  1000
# -2.86215594683 -2.91296882455
# calculation so far took 51.227142095565796  seconds
# step  10 of  1000
# -2.86215594683 -2.97309822633
# calculation so far took 55.09646773338318  seconds
# step  11 of  1000
# -2.86215594683 -3.07359667838
# calculation so far took 59.064034938812256  seconds
# step  12 of  1000
# -2.86215594683 -3.20566156894
# calculation so far took 64.76149368286133  seconds
# step  13 of  1000
# -2.86215594683 -3.47256947464
# calculation so far took 69.37409663200378  seconds
# step  14 of  1000
# -2.86215594683 -3.83156927018
# calculation so far took 74.36392664909363  seconds
# step  15 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -4.11360729498
# calculation so far took 78.18300247192383  seconds
# step  16 of  1000
# -2.86215594683 -4.36525254186
# calculation so far took 82.57558584213257  seconds
# step  17 of  1000
# -2.86215594683 -4.31319612297
# calculation so far took 86.31886196136475  seconds
# step  18 of  1000
# -2.86215594683 -4.51514538862
# calculation so far took 90.04472756385803  seconds
# step  19 of  1000
# -2.86215594683 -4.85906222291
# calculation so far took 93.78802275657654  seconds
# step  20 of  1000
# -2.86215594683 -4.72329210087
# calculation so far took 97.79268503189087  seconds
# step  21 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -4.8281392568
# calculation so far took 101.55302572250366  seconds
# step  22 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -4.7871368432
# calculation so far took 105.34835171699524  seconds
# step  23 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86215594683 -4.8542626632
# calculation so far took 109.08167052268982  seconds
# step  24 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -4.9627745254
# calculation so far took 113.48090171813965  seconds
# step  25 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: high_mass_slope lower border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86215594683 -5.03102573984
# calculation so far took 117.22667360305786  seconds
# step  26 of  1000
# -2.86215594683 -5.18639519997
# calculation so far took 120.96258592605591  seconds
# step  27 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: high_mass_slope lower border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -5.12412131796
# calculation so far took 124.92474293708801  seconds
# step  28 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: high_mass_slope lower border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -5.14622619991
# calculation so far took 129.22597336769104  seconds
# step  29 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: outflow_feedback_fraction lower border is violated
# -2.86215594683 -5.15837013349
# calculation so far took 133.1363170146942  seconds
# step  30 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -5.28391511314
# calculation so far took 136.99174666404724  seconds
# step  31 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -5.42662049521
# calculation so far took 140.78386068344116  seconds
# step  32 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: high_mass_slope lower border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: high_mass_slope lower border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: outflow_feedback_fraction upper border is violated
# -2.86215594683 -5.09266517904
# calculation so far took 144.7539620399475  seconds
# step  33 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86215594683 -5.2986311016
# calculation so far took 148.77184224128723  seconds
# step  34 of  1000
# -2.86215594683 -5.05896633772
# calculation so far took 153.03482174873352  seconds
# step  35 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -4.91415973057
# calculation so far took 157.26233100891113  seconds
# step  36 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -5.09968532467
# calculation so far took 161.36365962028503  seconds
# step  37 of  1000
# -2.86215594683 -5.20072967642
# calculation so far took 165.41277980804443  seconds
# step  38 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -5.20569172123
# calculation so far took 169.38772654533386  seconds
# step  39 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: outflow_feedback_fraction lower border is violated
# -2.86215594683 -5.25230937287
# calculation so far took 173.15376567840576  seconds
# step  40 of  1000
# -2.86215594683 -5.30567014911
# calculation so far took 177.1153588294983  seconds
# step  41 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86215594683 -5.17323596077
# calculation so far took 181.31892919540405  seconds
# step  42 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -5.26635508486
# calculation so far took 185.36576056480408  seconds
# step  43 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -5.55466100625
# calculation so far took 189.85613536834717  seconds
# step  44 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -5.44435205882
# calculation so far took 193.80020475387573  seconds
# step  45 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# -2.86215594683 -5.52009932098
# calculation so far took 197.93792724609375  seconds
# step  46 of  1000
# -2.86215594683 -5.24260566844
# calculation so far took 202.10257744789124  seconds
# step  47 of  1000
# -2.86215594683 -5.16783815773
# calculation so far took 206.2005581855774  seconds
# step  48 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: outflow_feedback_fraction upper border is violated
# -2.86215594683 -5.5907453119
# calculation so far took 210.14656591415405  seconds
# step  49 of  1000
# -2.86215594683 -5.44938358287
# calculation so far took 214.27569127082825  seconds
# step  50 of  1000
# -2.86215594683 -5.30300890157
# calculation so far took 218.63117861747742  seconds
# step  51 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86215594683 -5.19797926196
# calculation so far took 222.7155544757843  seconds
# step  52 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86215594683 -5.24851315132
# calculation so far took 226.7498869895935  seconds
# step  53 of  1000
# -2.86215594683 -5.44532889046
# calculation so far took 230.6937873363495  seconds
# step  54 of  1000
# -2.86215594683 -5.33648096185
# calculation so far took 234.95976662635803  seconds
# step  55 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
# ...
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: high_mass_slope lower border is violated
# -2.86215594683 -6.14034296283
# posterior -1, -100, -200 -6.14034296283 -6.04896660566 -6.19526551069
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1211.6861588954926  seconds
# step  286 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: outflow_feedback_fraction upper border is violated
# -2.86215594683 -6.1509592316
# posterior -1, -100, -200 -6.1509592316 -5.7298664011 -6.05773138212
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1215.5617172718048  seconds
# step  287 of  1000
# -2.86215594683 -6.04559843719
# posterior -1, -100, -200 -6.04559843719 -5.76070908498 -6.13785003325
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1219.6600954532623  seconds
# step  288 of  1000
# -2.86215594683 -5.83332806135
# posterior -1, -100, -200 -5.83332806135 -5.92713298743 -6.07269936386
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1224.2842297554016  seconds
# step  289 of  1000
# -2.86215594683 -5.73473396664
# posterior -1, -100, -200 -5.73473396664 -5.65263835475 -5.64784954624
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1228.6211087703705  seconds
# step  290 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86215594683 -6.03202247586
# posterior -1, -100, -200 -6.03202247586 -5.64000971751 -5.73262847218
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1233.0324821472168  seconds
# step  291 of  1000
# -2.86215594683 -5.91199341214
# posterior -1, -100, -200 -5.91199341214 -5.86169802787 -5.81492683499
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1237.5297112464905  seconds
# step  292 of  1000
# -2.86215594683 -6.15355098085
# posterior -1, -100, -200 -6.15355098085 -6.32436565182 -6.11651137557
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1241.5731573104858  seconds
# step  293 of  1000
# -2.86215594683 -6.28734190248
# posterior -1, -100, -200 -6.28734190248 -6.1842102086 -5.90276844604
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1245.7824614048004  seconds
# step  294 of  1000
# -2.86215594683 -6.3370907214
# posterior -1, -100, -200 -6.3370907214 -6.11151368287 -6.05582078446
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1250.531979084015  seconds
# step  295 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86215594683 -6.50922336126
# posterior -1, -100, -200 -6.50922336126 -5.94384931504 -5.89445581948
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1254.8364448547363  seconds
# step  296 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: high_mass_slope upper border is violated
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86215594683 -6.2384596335
# posterior -1, -100, -200 -6.2384596335 -5.81847088412 -5.86515150309
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1258.5760202407837  seconds
# step  297 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 510, in posterior_function_predictions
#     abundance_list,elements_to_trace = cem_real2(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 337, in cem_real2
#     a = shorten_sfr(a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 130, in shorten_sfr
#     assert fraction_of_mean_sfr > 0.05, ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', a.stellar_identifier, 'star time = ', star_time, 'model time = ', time_model )
# AssertionError: ('The total SFR of the last age bin is below 5% of the mean SFR', 'stellar identifier = ', 'Proto-sun', 'star time = ', 8.9400000000000013, 'model time = ', 9.0)
# -2.86215594683 -6.06069485821
# posterior -1, -100, -200 -6.06069485821 -5.59820887149 -5.64516783729
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1262.5029318332672  seconds
# step  298 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86215594683 -6.19629743419
# posterior -1, -100, -200 -6.19629743419 -5.74726960736 -5.57714757302
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1267.1201162338257  seconds
# step  299 of  1000
# -2.86215594683 -5.94774466967
# posterior -1, -100, -200 -5.94774466967 -5.690274687 -5.480601597
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1271.8008286952972  seconds
# step  300 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 722, in extract_parameters_and_priors
#     assert False, '%s upper border is violated' %(name)
# AssertionError: log10_sfr_scale upper border is violated
# -2.86215594683 -5.88215645044
# posterior -1, -100, -200 -5.88215645044 -5.5621691084 -5.44369238807
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1276.259000301361  seconds
# step  301 of  1000
# Traceback (most recent call last):
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 885, in posterior_function_many_stars
#     posterior, blobs = posterior_function_many_stars_real(changing_parameter,error_list,elements)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 923, in posterior_function_many_stars_real
#     abundance_list,element_list = posterior_function_returning_predictions(args)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 484, in posterior_function_returning_predictions
#     posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 495, in posterior_function_predictions
#     a = extract_parameters_and_priors(changing_parameter, a)
#   File "/home/philcox/Chempy/Chempy/cem_function.py", line 720, in extract_parameters_and_priors
#     assert False, '%s lower border is violated' %(name)
# AssertionError: outflow_feedback_fraction lower border is violated
# -2.86215594683 -5.84869265904
# posterior -1, -100, -200 -5.84869265904 -5.4896632665 -5.65162164219
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1280.0544385910034  seconds
# step  302 of  1000
# -2.86215594683 -5.8526642012
# posterior -1, -100, -200 -5.8526642012 -5.48959952146 -5.73562924897
# posterior 0, 100, 200 -2.86215594683 -5.480601597 -5.690274687
# calculation so far took 1283.9086306095123  seconds
# 1 loop, best of 1: 22min 9s per loop

# %% [markdown]
# **Output from multi_star_optimization is shown below** - time is 1h 4min 58s
#
# -85.3060153739 -86.2401397753
# posterior -1, -100, -200 -86.2401397753 -86.3245589017 -85.9632092474
# posterior 0, 100, 200 -85.3060153739 -86.0016467311 -86.1845593497
# calculation so far took 3591.1689043045044  seconds
# step  302 of  1000
# -85.3060153739 -86.470086954
# posterior -1, -100, -200 -86.470086954 -86.2141620897 -86.0988536579
# posterior 0, 100, 200 -85.3060153739 -86.0016467311 -86.1845593497
# calculation so far took 3602.9518530368805  seconds
# 1 loop, best of 1: 1h 4min 58s per loop

# %%
## Now restructure the chain

from Chempy.plot_mcmc import restructure_chain
restructure_chain('karakas10_zero_error/')
# Out:
# blob shape =  (64, 303, 22, 1) probably some runs did not return results and were stored anyway.
# The chain has a length of 303 iterations, each iteration having 64 evaluations/walkers
# Mean posteriors at the beginning and the end of the chain:
# -86.470086954 -85.3060153739
# Mean posteriors after the burn-in tail is cut out:
# -86.470086954 -86.4301972379
# We are left with a sample of 4992 posterior evaluations from the converged MCMC chain
# We have 4992 iterations good enough posterior, their posteriors range from
# -83.406933793 -97.7149046464
# Highest posterior was obtained at parameters:  [[-2.81650001 -3.09279738 -0.71551012 -0.3070466   0.40369205  0.35295788]]
# Number of unique posterior values:  2489
# Inferred marginalized parameter distributions are:
# 0 -2.80044768806 +- 0.0477896985216
# 1 -3.06761644287 +- 0.0983004189356
# 2 -0.823700514436 +- 0.309972578189
# 3 -0.259356646202 +- 0.106207689159
# 4 0.42292732182 +- 0.0712252101051
# 5 0.363100221775 +- 0.0833858353826

# %%
## Plot the posterior and prior values and correlation grid
from Chempy.plot_mcmc import plot_mcmc_chain_with_prior
plot_mcmc_chain_with_prior('karakas10_zero_error/',use_prior = True, only_first_star = False,plot_true_parameters = False,plot_only_SSP_parameter = False)

# %%
# Create output for best-fit parameters
from Chempy.cem_function import cem2, extract_parameters_and_priors
from Chempy.parameter import ModelParameters
a=ModelParameters()
a.p0 = np.array([-2.80,-3.06,-0.83,-0.26,0.43,0.36]) # Parameters found by model
a = extract_parameters_and_priors(a.p0, a) # To update to new model
abundances, names = cem2(a) # predict abundances

# %%
# Load in proto-sun abundances and errors (remove last value (solar age))
proto_sun = np.load('Chempy/input/stars/Proto-sun.npy')
proto_sun_abundance = []
proto_sun_error = []
model_abundance = []

# Calculate model abundance in same order as proto-sun
for i,item in enumerate(proto_sun.dtype.names[:-1]):
    for j,jtem in enumerate(names):
        if jtem == item:
            model_abundance.append(abundances[j])
    #model_abundance.append(abundances[np.where(names==item)])
    proto_sun_abundance.append(proto_sun[0][i])
    proto_sun_error.append(proto_sun[1][i])
    
# Load abundance names ([X/Fe]) in correct order
abundance_names = []
for item in proto_sun.dtype.names[:-1]:
    if item != 'Fe':
        abundance_names.append('[%s/Fe]' %(item))
    else:
        abundance_names.append('[Fe/H]')

# %%
# Plot figure
fig = plt.figure(figsize=(30.69,8.27), dpi=100)
plt.clf()
text_size = 20
plt.rc('font', family='serif',size = text_size)
plt.rc('xtick', labelsize=text_size)
plt.rc('ytick', labelsize=text_size)
plt.rc('axes', labelsize=text_size, lw=1.)
plt.rc('lines', linewidth = 1.)
plt.rcParams['ytick.major.pad']='8'
plt.rcParams['text.latex.preamble']=[r"\usepackage{libertine}"]
params = {'text.usetex' : True,'font.size' : 16,'font.family' : 'libertine','text.latex.unicode': True}
ax = fig.add_subplot(111)
plt.plot(np.arange(len(abundance_names)),model_abundance,label='Final model abundances',linestyle='-') # Plot model data
plt.errorbar(np.arange(len(abundance_names)),proto_sun_abundance,xerr=None,yerr=proto_sun_error,linestyle = '',mew=3,marker='x',capthick =3,capsize = 20, ms = 10,elinewidth=3,label='proto-solar')
plt.ylim((-0.5,0.5))
plt.xticks(np.arange(len(a.element_names)),abundance_names)
plt.ylabel("abundance relative to solar in dex")
plt.xlabel("Element")
plt.title("Comparing proto-solar model and predicted abundances")
plt.legend()
savefig('karakas10_zero_error/AbundancePlot')
